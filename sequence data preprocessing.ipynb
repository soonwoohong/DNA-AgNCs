# %%
# !pip install --upgrade keras-nlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# this is a training code for preprocessing DNA data for a transformer.
# toeknizer

import pandas as pd
import os
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers

import keras_nlp

# %%
data_file = '/content/drive/MyDrive/github_commit/DNA-AgNCs/data/Michael_chip_data_red.xlsx'
data_xls = pd.ExcelFile(data_file)
data_xls.sheet_names
# Out:
# ['library_1, batch1,red',
#  'library_1, batch2,red',
#  'library_1, batch3,red',
#  'library_2,batch1,red',
#  'library_2,batch2,red',
#  'library_2,batch3,red',
#  'library_3,batch1,red',
#  'library_3,batch2,red',
#  'library_3,batch3,red']

# %%
data = pd.read_excel(data_file,sheet_name = data_xls.sheet_names[0])
data
# Out:
#                               Seq  ...  number of polonies
# 0      TCCACTGGTGGGGTGGGGCGCGCGCG  ...                 291
# 1      TCCCATGGTGGGGTGGGGCGCGCGCG  ...                 277
# 2      TCCATTGGTGGGGTGGGGCGCGCGCG  ...                 629
# 3      TCCAATGGTGGGGTGGGGCGCGCGCG  ...                 442
# 4      TCCATAGGTGGGGTGGGGCGCGCGCG  ...                 415
# ...                           ...  ...                 ...
# 12281  GGGTGGATCGCCGTGGGGCGCGCGCG  ...                 163
# 12282  GGGTGGCCACAAGTGGGGCGCGCGCG  ...                 102
# 12283  GGGTGGATCTCCGTGGGGCGCGCGCG  ...                 199
# 12284  GGGTGGGGTGGGCCCCCACGCGCGCG  ...                  60
# 12285  GGGTGGCCTCCAGTGGGGCGCGCGCG  ...                  81
#
# [12286 rows x 4 columns]

# %%
# in this example, the length of sequence is same.
# (TODO) in case the lengh is different

seq = 'GGGATCAATGGGGTGGGG'

def seq_kmer(seq, kk = 2):
  output = [seq[i:i+kk] for i in range(len(seq)-kk+1)]
  return output



# method 1: one base to one token
seq_one = seq_kmer(seq,1)

# TODO method 2: n-mer to one token (with overlap)
#seq_two = seq_kmer(seq,2)

# TODO: method 3: n-mer to one token (without overlap)

# %%
vocab = {'[UNK]', 'A', 'C': 2, 'G': 3, 'T':4 }

tokenizer = keras_nlp.tokenizers.BytePairTokenizer(vocabulary=vocab, sequence_length = len(seq))

'''
tokenizer = Tokenizer(vocabulary = vocab, sequence_length = len(seq))
tokenizer.fit_on_texts(seq_one)
VOCAB_SIZE = len(word_index)
VOCAB_SIZE
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-ef0aa905a029> in <module>
#       1 vocab = {'A': 1, 'C': 2, 'G': 3, 'T':4 }
#       2
# ----> 3 tokenizer = keras_nlp.tokenizers.BytePairTokenizer(vocabulary=vocab, sequence_length = len(seq))
#       4
#       5 '''
#
# TypeError: __init__() missing 1 required positional argument: 'merges'

# %%
vocab
# Out:
# {'A': 1, 'C': 2, 'G': 3, 'T': 4}

# %%
import numpy as np


def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

n_classes = len(np.unique(y_train))

idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %%
x_train.shape
# Out:
# (3601, 500, 1)
